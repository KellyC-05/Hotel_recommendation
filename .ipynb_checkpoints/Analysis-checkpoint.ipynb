# %%
#import all necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#unzip downloaded files

#install library
# !pip install zipfile36

#import library
import zipfile

#unzipping
train_data = zipfile.ZipFile('train.csv.zip')
test_data = zipfile.ZipFile('test.csv.zip')

#extract both data
train_data.extractall()
test_data.extractall()

#close both data
train_data.close()
test_data.close()

#load datasets
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

print(train.shape)
print(test.shape)

#random sampling to reduce the size of datasets 
#select 10 percent of rows, can be changed
train = train.sample(frac = 0.01, random_state = 1)
test = test.sample(frac = 0.01, random_state = 1)

#save sampled dataframe as new file
train.to_csv('train_0.01.csv', index = False)
test.to_csv('test_0.01.csv', index = False)
# Out:
# Requirement already satisfied: zipfile36 in c:\users\kelly\anaconda3\lib\site-packages (0.1.3)
# (37670293, 24)
# (2528243, 22)

# %%
#load sampled datasets 
train = pd.read_csv('train_0.01.csv')
test = pd.read_csv('test_0.01.csv')
print(train.shape)
print(test.shape)
# Out:
# (376703, 24)
# (25282, 22)

# %%
#clean data with empty cells
train = train.dropna()
test = test.dropna()
print(train.shape)
print(test.shape)
# Out:
# (241443, 24)
# (16676, 22)

# %%
train.head()
# Out:
#              date_time  site_name  posa_continent  user_location_country  \
# 0  2014-09-13 17:23:58         11               3                    205
# 1  2014-11-17 19:56:32         11               3                    205
# 3  2014-09-05 14:48:31         11               3                    205
# 5  2013-07-09 10:19:54          2               3                     66
# 6  2014-11-10 08:27:04          2               3                     66
#
#    user_location_region  user_location_city  orig_destination_distance  \
# 0                   354               21728                  2183.8227
# 1                   385               46963                  1843.0431
# 3                   354               25315                    43.5909
# 5                   348               48862                   284.0528
# 6                   348                 332                  1018.7654
#
#    user_id  is_mobile  is_package  ...  srch_children_cnt srch_rm_cnt  \
# 0   543652          0           0  ...                  0           1
# 1   963724          0           0  ...                  0           1
# 3   674104          0           0  ...                  1           1
# 5   405311          0           0  ...                  0           1
# 6   980005          1           0  ...                  0           1
#
#   srch_destination_id  srch_destination_type_id  is_booking  cnt  \
# 0                8854                         1           0    1
# 1                8791                         1           0    2
# 3               14875                         1           0    1
# 5                3776                         3           0    1
# 6               15093                         1           0    3
#
#    hotel_continent  hotel_country  hotel_market  hotel_cluster
# 0                2            198           402             74
# 1                4              8           110             85
# 3                2            198           750             98
# 5                2             50          1191             77
# 6                2             50           679             17
#
# [5 rows x 24 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 241443 entries, 0 to 376702
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   date_time                  241443 non-null  object
#  1   site_name                  241443 non-null  int64
#  2   posa_continent             241443 non-null  int64
#  3   user_location_country      241443 non-null  int64
#  4   user_location_region       241443 non-null  int64
#  5   user_location_city         241443 non-null  int64
#  6   orig_destination_distance  241443 non-null  float64
#  7   user_id                    241443 non-null  int64
#  8   is_mobile                  241443 non-null  int64
#  9   is_package                 241443 non-null  int64
#  10  channel                    241443 non-null  int64
#  11  srch_ci                    241443 non-null  object
#  12  srch_co                    241443 non-null  object
#  13  srch_adults_cnt            241443 non-null  int64
#  14  srch_children_cnt          241443 non-null  int64
#  15  srch_rm_cnt                241443 non-null  int64
#  16  srch_destination_id        241443 non-null  int64
#  17  srch_destination_type_id   241443 non-null  int64
#  18  is_booking                 241443 non-null  int64
#  19  cnt                        241443 non-null  int64
#  20  hotel_continent            241443 non-null  int64
#  21  hotel_country              241443 non-null  int64
#  22  hotel_market               241443 non-null  int64
#  23  hotel_cluster              241443 non-null  int64
# dtypes: float64(1), int64(20), object(3)
# memory usage: 46.1+ MB

# %%
test.head()
# Out:
#         id            date_time  site_name  posa_continent  \
# 0  1602422  2015-05-22 18:26:56          2               3
# 1  2073388  2015-01-16 09:21:53          2               3
# 4  2096148  2015-11-02 13:19:19          2               3
# 8  2477994  2015-12-14 10:35:53          2               3
# 9  2105664  2015-11-25 14:35:08          2               3
#
#    user_location_country  user_location_region  user_location_city  \
# 0                    215                   914               33757
# 1                     66                   153               23511
# 4                     66                   318               29466
# 8                     66                   174               30495
# 9                     66                   356               47475
#
#    orig_destination_distance  user_id  is_mobile  ...     srch_ci     srch_co  \
# 0                  5816.4927   524141          1  ...  2015-07-03  2015-07-05
# 1                  2121.1750   890108          0  ...  2015-03-05  2015-03-12
# 4                  7972.6709   965762          0  ...  2015-11-17  2015-11-19
# 8                  2135.0599  1034430          0  ...  2016-01-03  2016-01-07
# 9                   133.9984   994963          0  ...  2015-11-26  2015-11-27
#
#   srch_adults_cnt srch_children_cnt  srch_rm_cnt  srch_destination_id  \
# 0               2                 0            1                 8234
# 1               3                 0            1                 8267
# 4               3                 0            3                41323
# 8               1                 0            1                 8268
# 9               2                 0            1                23601
#
#    srch_destination_type_id  hotel_continent  hotel_country  hotel_market
# 0                         1                6              7             8
# 1                         1                2             50           675
# 4                         1                3            104            84
# 8                         1                2             50           682
# 9                         6                2             50           660
#
# [5 rows x 22 columns]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16676 entries, 0 to 25279
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         16676 non-null  int64
#  1   date_time                  16676 non-null  object
#  2   site_name                  16676 non-null  int64
#  3   posa_continent             16676 non-null  int64
#  4   user_location_country      16676 non-null  int64
#  5   user_location_region       16676 non-null  int64
#  6   user_location_city         16676 non-null  int64
#  7   orig_destination_distance  16676 non-null  float64
#  8   user_id                    16676 non-null  int64
#  9   is_mobile                  16676 non-null  int64
#  10  is_package                 16676 non-null  int64
#  11  channel                    16676 non-null  int64
#  12  srch_ci                    16676 non-null  object
#  13  srch_co                    16676 non-null  object
#  14  srch_adults_cnt            16676 non-null  int64
#  15  srch_children_cnt          16676 non-null  int64
#  16  srch_rm_cnt                16676 non-null  int64
#  17  srch_destination_id        16676 non-null  int64
#  18  srch_destination_type_id   16676 non-null  int64
#  19  hotel_continent            16676 non-null  int64
#  20  hotel_country              16676 non-null  int64
#  21  hotel_market               16676 non-null  int64
# dtypes: float64(1), int64(18), object(3)
# memory usage: 2.9+ MB

# %% [markdown]
# # Data Exploration

# %%
print(train['is_booking'].unique().tolist())
# Out:
# [0, 1]

# %%
# Plot the count of hotel_cluster distribution
plt.hist(train['hotel_cluster'], bins = 20)
plt.title('Hotel Cluster in Training Data')
plt.ylabel('Count')
plt.xlabel('Hotel cluster')
# Out:
# Text(0.5, 0, 'Hotel cluster')

# %%
#create a correlation matrix to see relationship of training data
corr = train.corr()

matrix = np.triu(corr)
plt.subplots(figsize=(20,15))
sns.set(font_scale=1.4)
plt.title('Heatmap of Training Data')
sns.heatmap(corr, annot = True, mask = matrix, annot_kws = {"size": 16})
# Out:
# <AxesSubplot:title={'center':'Heatmap of Training Data'}>

# %%
#create a correlation matrix to see relationship of test data
corr = test.corr()

matrix = np.triu(corr)
plt.subplots(figsize=(20,15))
sns.set(font_scale=1.4)
plt.title('Heatmap of Test Data')
sns.heatmap(corr, annot = True, mask = matrix, annot_kws = {"size": 16})
# Out:
# <AxesSubplot:title={'center':'Heatmap of Test Data'}>

# %%
#drop data that does not book 'is_booking = 0'
train_book = train.drop(train[train['is_booking'] < 1].index)
# print(train_book)

#count each cluster is book
book_cluster = train_book.groupby(['hotel_cluster'])['is_booking'].agg(['count'])
print(book_cluster)

#histogram of count each cluster is book
plt.hist(train_book['hotel_cluster'], bins = 20)
plt.title('Booked Hotel Cluster in Training Data')
plt.ylabel('Number booking')
plt.xlabel('Hotel cluster')
# Out:
#                count
# hotel_cluster
# 0                168
# 1                309
# 2                248
# 3                 73
# 4                273
# ...              ...
# 95               460
# 96               132
# 97               185
# 98               341
# 99               210
#
# [100 rows x 1 columns]
# Text(0.5, 0, 'Hotel cluster')

# %%
#grouped the data by the hotel location and count each columns
country_market = train.groupby(['hotel_continent', 'hotel_country']).agg(['count'])
print(country_market)
# Out:
#                               date_time site_name posa_continent  \
#                                   count     count          count
# hotel_continent hotel_country
# 0               34                  499       499            499
#                 63                 2453      2453           2453
#                 87                  375       375            375
#                 95                    2         2              2
#                 114                   3         3              3
# ...                                 ...       ...            ...
# 6               204                5314      5314           5314
#                 206                  77        77             77
#                 208                1419      1419           1419
#                 211                  11        11             11
#                 212                  18        18             18
#
#                               user_location_country user_location_region  \
#                                               count                count
# hotel_continent hotel_country
# 0               34                              499                  499
#                 63                             2453                 2453
#                 87                              375                  375
#                 95                                2                    2
#                 114                               3                    3
# ...                                             ...                  ...
# 6               204                            5314                 5314
#                 206                              77                   77
#                 208                            1419                 1419
#                 211                              11                   11
#                 212                              18                   18
#
#                               user_location_city orig_destination_distance  \
#                                            count                     count
# hotel_continent hotel_country
# 0               34                           499                       499
#                 63                          2453                      2453
#                 87                           375                       375
#                 95                             2                         2
#                 114                            3                         3
# ...                                          ...                       ...
# 6               204                         5314                      5314
#                 206                           77                        77
#                 208                         1419                      1419
#                 211                           11                        11
#                 212                           18                        18
#
#                               user_id is_mobile is_package  ... srch_co  \
#                                 count     count      count  ...   count
# hotel_continent hotel_country                               ...
# 0               34                499       499        499  ...     499
#                 63               2453      2453       2453  ...    2453
#                 87                375       375        375  ...     375
#                 95                  2         2          2  ...       2
#                 114                 3         3          3  ...       3
# ...                               ...       ...        ...  ...     ...
# 6               204              5314      5314       5314  ...    5314
#                 206                77        77         77  ...      77
#                 208              1419      1419       1419  ...    1419
#                 211                11        11         11  ...      11
#                 212                18        18         18  ...      18
#
#                               srch_adults_cnt srch_children_cnt srch_rm_cnt  \
#                                         count             count       count
# hotel_continent hotel_country
# 0               34                        499               499         499
#                 63                       2453              2453        2453
#                 87                        375               375         375
#                 95                          2                 2           2
#                 114                         3                 3           3
# ...                                       ...               ...         ...
# 6               204                      5314              5314        5314
#                 206                        77                77          77
#                 208                      1419              1419        1419
#                 211                        11                11          11
#                 212                        18                18          18
#
#                               srch_destination_id srch_destination_type_id  \
#                                             count                    count
# hotel_continent hotel_country
# 0               34                            499                      499
#                 63                           2453                     2453
#                 87                            375                      375
#                 95                              2                        2
#                 114                             3                        3
# ...                                           ...                      ...
# 6               204                          5314                     5314
#                 206                            77                       77
#                 208                          1419                     1419
#                 211                            11                       11
#                 212                            18                       18
#
#                               is_booking   cnt hotel_market hotel_cluster
#                                    count count        count         count
# hotel_continent hotel_country
# 0               34                   499   499          499           499
#                 63                  2453  2453         2453          2453
#                 87                   375   375          375           375
#                 95                     2     2            2             2
#                 114                    3     3            3             3
# ...                                  ...   ...          ...           ...
# 6               204                 5314  5314         5314          5314
#                 206                   77    77           77            77
#                 208                 1419  1419         1419          1419
#                 211                   11    11           11            11
#                 212                   18    18           18            18
#
# [182 rows x 22 columns]

# %%
#grouped the data and count the cluster
book_package_custer = train.groupby(['is_booking', 'is_package', 'hotel_cluster'])['hotel_cluster'].agg(['count'])
print(book_package_custer)
# Out:
#                                      count
# is_booking is_package hotel_cluster
# 0          0          0               1551
#                       1               1882
#                       2               1595
#                       3                863
#                       4               1998
# ...                                    ...
# 1          1          95                72
#                       96                39
#                       97                36
#                       98                66
#                       99                16
#
# [398 rows x 1 columns]

# %%
# Create bar chart
plt.bar(train['hotel_cluster'], train['hotel_market'])

fig = plt.gcf()
fig.set_size_inches(15, 10)

# Add axis labels and title
plt.xlabel('Cluster')
plt.ylabel('Market')
plt.title('Hotel Cluster and Market')

# Show plot
plt.show()

# %% [markdown]
# # Preprocessing
